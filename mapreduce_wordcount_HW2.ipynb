# %% [markdown]
# ### Name : Lokesh Chava
# ### ID: YJ56814

# %%
# Date of Birth : April 24, 2001
import collections
import re
file = open("file1.txt", "r")
wordcount = {}
for line in file:
    words = line.split()
    for word in words:
        word = re.sub(r'\W', '', word)
        if word in wordcount:
            wordcount[word] += 1
        else:
            wordcount[word] = 1
sorted_wordcount = collections.OrderedDict(sorted(wordcount.items(), key=lambda x: x[1], reverse=True))

# %%
sorted_wordcount
# Out:
# OrderedDict([('the', 119),
#              ('to', 80),
#              ('had', 75),
#              ('and', 71),
#              ('of', 65),
#              ('Harry', 62),
#              ('he', 58),
#              ('was', 45),
#              ('his', 42),
#              ('a', 41),
#              ('', 40),
#              ('that', 34),
#              ('Uncle', 28),
#              ('at', 25),
#              ('for', 24),
#              ('Vernon', 23),
#              ('him', 21),
#              ('with', 21),
#              ('in', 20),
#              ('it', 19),
#              ('Sirius', 19),
#              ('been', 18),
#              ('as', 17),
#              ('from', 16),
#              ('Aunt', 16),
#              ('on', 15),
#              ('Petunia', 14),
#              ('up', 12),
#              ('this', 12),
#              ('Page', 11),
#              ('Potter', 11),
#              ('Goblet', 11),
#              ('Fire', 11),
#              ('JK', 11),
#              ('Rowling', 11),
#              ('have', 11),
#              ('said', 11),
#              ('then', 10),
#              ('when', 10),
#              ('them', 10),
#              ('down', 9),
#              ('all', 9),
#              ('out', 9),
#              ('be', 9),
#              ('school', 9),
#              ('you', 9),
#              ('didnt', 9),
#              ('He', 9),
#              ('Dudley', 9),
#              ('so', 8),
#              ('Harrys', 8),
#              ('by', 8),
#              ('Dursleys', 8),
#              ('The', 8),
#              ('not', 8),
#              ('were', 8),
#              ('into', 8),
#              ('looked', 8),
#              ('which', 7),
#              ('now', 7),
#              ('they', 7),
#              ('back', 7),
#              ('letter', 7),
#              ('got', 7),
#              ('I', 7),
#              ('grapefruit', 7),
#              ('about', 7),
#              ('Mrs', 7),
#              ('would', 7),
#              ('room', 6),
#              ('who', 6),
#              ('though', 6),
#              ('could', 6),
#              ('if', 6),
#              ('summer', 6),
#              ('even', 6),
#              ('but', 6),
#              ('her', 6),
#              ('off', 6),
#              ('get', 6),
#              ('too', 6),
#              ('what', 6),
#              ('came', 5),
#              ('But', 5),
#              ('two', 5),
#              ('come', 5),
#              ('since', 5),
#              ('might', 5),
#              ('under', 5),
#              ('large', 5),
#              ('Hedwig', 5),
#              ('put', 5),
#              ('Dudleys', 5),
#              ('know', 5),
#              ('Vernons', 5),
#              ('than', 5),
#              ('something', 5),
#              ('So', 5),
#              ('It', 4),
#              ('long', 4),
#              ('thought', 4),
#              ('after', 4),
#              ('found', 4),
#              ('Hogwarts', 4),
#              ('escaped', 4),
#              ('Wormtail', 4),
#              ('their', 4),
#              ('because', 4),
#              ('before', 4),
#              ('things', 4),
#              ('never', 4),
#              ('letters', 4),
#              ('usual', 4),
#              ('himself', 4),
#              ('needed', 4),
#              ('seemed', 4),
#              ('my', 4),
#              ('are', 4),
#              ('diet', 4),
#              ('really', 4),
#              ('can', 4),
#              ('time', 4),
#              ('face', 4),
#              ('quarter', 4),
#              ('boy', 4),
#              ('see', 4),
#              ('sent', 4),
#              ('make', 4),
#              ('She', 4),
#              ('sure', 4),
#              ('own', 4),
#              ('Weasley', 4),
#              ('do', 4),
#              ('stamps', 4),
#              ('Weasleys', 4),
#              ('desk', 3),
#              ('parchment', 3),
#              ('Dear', 3),
#              ('how', 3),
#              ('best', 3),
#              ('still', 3),
#              ('fact', 3),
#              ('away', 3),
#              ('only', 3),
#              ('There', 3),
#              ('life', 3),
#              ('called', 3),
#              ('believed', 3),
#              ('Ron', 3),
#              ('however', 3),
#              ('last', 3),
#              ('home', 3),
#              ('take', 3),
#              ('hard', 3),
#              ('bedroom', 3),
#              ('she', 3),
#              ('most', 3),
#              ('again', 3),
#              ('hand', 3),
#              ('why', 3),
#              ('hidden', 3),
#              ('heard', 3),
#              ('finished', 3),
#              ('enormous', 3),
#              ('through', 3),
#              ('going', 3),
#              ('turn', 3),
#              ('A', 3),
#              ('hurt', 3),
#              ('years', 3),
#              ('look', 3),
#              ('more', 3),
#              ('already', 3),
#              ('table', 3),
#              ('behind', 3),
#              ('over', 3),
#              ('report', 3),
#              ('find', 3),
#              ('very', 3),
#              ('little', 3),
#              ('son', 3),
#              ('nurse', 3),
#              ('food', 3),
#              ('enough', 3),
#              ('eyes', 3),
#              ('many', 3),
#              ('cakes', 3),
#              ('feel', 3),
#              ('way', 3),
#              ('did', 3),
#              ('house', 3),
#              ('full', 3),
#              ('paper', 3),
#              ('mustache', 3),
#              ('door', 3),
#              ('where', 3),
#              ('just', 3),
#              ('writing', 3),
#              ('Who', 3),
#              ('postman', 3),
#              ('is', 3),
#              ('anyone', 3),
#              ('say', 3),
#              ('anything', 3),
#              ('And', 2),
#              ('simple', 2),
#              ('couldnt', 2),
#              ('taken', 2),
#              ('bed', 2),
#              ('sat', 2),
#              ('piece', 2),
#              ('wondering', 2),
#              ('hadnt', 2),
#              ('perhaps', 2),
#              ('godfather', 2),
#              ('Siriuss', 2),
#              ('dementors', 2),
#              ('innocent', 2),
#              ('nearly', 2),
#              ('Hermione', 2),
#              ('knew', 2),
#              ('one', 2),
#              ('once', 2),
#              ('name', 2),
#              ('cleared', 2),
#              ('Buckbeak', 2),
#              ('some', 2),
#              ('help', 2),
#              ('possible', 2),
#              ('fear', 2),
#              ('received', 2),
#              ('delivered', 2),
#              ('these', 2),
#              ('allow', 2),
#              ('other', 2),
#              ('mind', 2),
#              ('hoped', 2),
#              ('loose', 2),
#              ('floorboard', 2),
#              ('both', 2),
#              ('call', 2),
#              ('ever', 2),
#              ('right', 2),
#              ('risen', 2),
#              ('walls', 2),
#              ('Petunias', 2),
#              ('your', 2),
#              ('window', 2),
#              ('My', 2),
#              ('They', 2),
#              ('told', 2),
#              ('pocket', 2),
#              ('Thats', 2),
#              ('sort', 2),
#              ('thing', 2),
#              ('stupid', 2),
#              ('hasnt', 2),
#              ('happened', 2),
#              ('morning', 2),
#              ('me', 2),
#              ('send', 2),
#              ('moment', 2),
#              ('no', 2),
#              ('want', 2),
#              ('laid', 2),
#              ('aside', 2),
#              ('returned', 2),
#              ('Then', 2),
#              ('breakfast', 2),
#              ('arrived', 2),
#              ('kitchen', 2),
#              ('three', 2),
#              ('around', 2),
#              ('or', 2),
#              ('red', 2),
#              ('teeth', 2),
#              ('furious', 2),
#              ('This', 2),
#              ('always', 2),
#              ('an', 2),
#              ('square', 2),
#              ('onto', 2),
#              ('His', 2),
#              ('unpleasant', 2),
#              ('managed', 2),
#              ('insisted', 2),
#              ('understand', 2),
#              ('while', 2),
#              ('much', 2),
#              ('seen', 2),
#              ('To', 2),
#              ('family', 2),
#              ('noticed', 2),
#              ('keep', 2),
#              ('upstairs', 2),
#              ('Hermiones', 2),
#              ('Hagrid', 2),
#              ('Errol', 2),
#              ('birthday', 2),
#              ('looking', 2),
#              ('gave', 2),
#              ('severe', 2),
#              ('great', 2),
#              ('doorbell', 2),
#              ('rang', 2),
#              ('set', 2),
#              ('hall', 2),
#              ('mother', 2),
#              ('rest', 2),
#              ('someone', 2),
#              ('front', 2),
#              ('closed', 2),
#              ('sound', 2),
#              ('minute', 2),
#              ('temper', 2),
#              ('purple', 2),
#              ('aloud', 2),
#              ('Dursley', 2),
#              ('We', 2),
#              ('am', 2),
#              ('has', 2),
#              ('tickets', 2),
#              ('hope', 2),
#              ('us', 2),
#              ('train', 2),
#              ('growled', 2),
#              ('bit', 2),
#              ('trying', 2),
#              ('uncles', 2),
#              ('people', 2),
#              ('go', 2),
#              ('woman', 2),
#              ('finally', 2),
#              ('24', 1),
#              ('solution', 1),
#              ('obvious', 1),
#              ('believe', 1),
#              ('leapt', 1),
#              ('hurried', 1),
#              ('across', 1),
#              ('pulled', 1),
#              ('toward', 1),
#              ('loaded', 1),
#              ('eaglefeather', 1),
#              ('quill', 1),
#              ('ink', 1),
#              ('wrote', 1),
#              ('paused', 1),
#              ('phrase', 1),
#              ('problem', 1),
#              ('marveling', 1),
#              ('straight', 1),
#              ('wasnt', 1),
#              ('surprising', 1),
#              ('months', 1),
#              ('ago', 1),
#              ('reason', 1),
#              ('complete', 1),
#              ('absence', 1),
#              ('until', 1),
#              ('Azkaban', 1),
#              ('terrifying', 1),
#              ('wizard', 1),
#              ('jail', 1),
#              ('guarded', 1),
#              ('creatures', 1),
#              ('sightless', 1),
#              ('soulsucking', 1),
#              ('fiends', 1),
#              ('search', 1),
#              ('Yet', 1),
#              ('murders', 1),
#              ('convicted', 1),
#              ('committed', 1),
#              ('Voldemorts', 1),
#              ('supporter', 1),
#              ('whom', 1),
#              ('everybody', 1),
#              ('dead', 1),
#              ('otherwise', 1),
#              ('facetoface', 1),
#              ('previous', 1),
#              ('year', 1),
#              ('Professor', 1),
#              ('Dumbledore', 1),
#              ('story', 1),
#              ('For', 1),
#              ('glorious', 1),
#              ('hour', 1),
#              ('leaving', 1),
#              ('offered', 1),
#              ('chance', 1),
#              ('snatched', 1),
#              ('Ministry', 1),
#              ('Magic', 1),
#              ('flee', 1),
#              ('helped', 1),
#              ('escape', 1),
#              ('hippogriff', 1),
#              ('run', 1),
#              ('haunting', 1),
#              ('doubly', 1),
#              ('return', 1),
#              ('25', 1),
#              ('knowing', 1),
#              ('forever', 1),
#              ('Nevertheless', 1),
#              ('due', 1),
#              ('allowed', 1),
#              ('general', 1),
#              ('wish', 1),
#              ('keeping', 1),
#              ('miserable', 1),
#              ('coupled', 1),
#              ('powers', 1),
#              ('led', 1),
#              ('lock', 1),
#              ('trunk', 1),
#              ('cupboard', 1),
#              ('stairs', 1),
#              ('every', 1),
#              ('prior', 1),
#              ('attitude', 1),
#              ('changed', 1),
#              ('dangerous', 1),
#              ('murderer', 1),
#              ('conveniently', 1),
#              ('forgotten', 1),
#              ('tell', 1),
#              ('Privet', 1),
#              ('Drive', 1),
#              ('Both', 1),
#              ('owls', 1),
#              ('wizards', 1),
#              ('brightly', 1),
#              ('colored', 1),
#              ('tropical', 1),
#              ('birds', 1),
#              ('approved', 1),
#              ('flashy', 1),
#              ('intruders', 1),
#              ('reluctant', 1),
#              ('drink', 1),
#              ('water', 1),
#              ('tray', 1),
#              ('flying', 1),
#              ('liked', 1),
#              ('palm', 1),
#              ('trees', 1),
#              ('white', 1),
#              ('sand', 1),
#              ('wherever', 1),
#              ('case', 1),
#              ('intercepted', 1),
#              ('enjoying', 1),
#              ('Somehow', 1),
#              ('imagine', 1),
#              ('surviving', 1),
#              ('bright', 1),
#              ('sunlight', 1),
#              ('gone', 1),
#              ('south', 1),
#              ('beneath', 1),
#              ('highly', 1),
#              ('useful', 1),
#              ('sounded', 1),
#              ('cheerful', 1),
#              ('reminded', 1),
#              ('Well', 1),
#              ('lamp', 1),
#              ('grow', 1),
#              ('dimmer', 1),
#              ('cold', 1),
#              ('gray', 1),
#              ('light', 1),
#              ('precedes', 1),
#              ('sunrise', 1),
#              ('slowly', 1),
#              ('crept', 1),
#              ('Finally', 1),
#              ('sun', 1),
#              ('26', 1),
#              ('turned', 1),
#              ('gold', 1),
#              ('sounds', 1),
#              ('movement', 1),
#              ('crumpled', 1),
#              ('pieces', 1),
#              ('reread', 1),
#              ('Thanks', 1),
#              ('That', 1),
#              ('bird', 1),
#              ('hardly', 1),
#              ('Things', 1),
#              ('same', 1),
#              ('here', 1),
#              ('isnt', 1),
#              ('well', 1),
#              ('aunt', 1),
#              ('smuggling', 1),
#              ('doughnuts', 1),
#              ('yesterday', 1),
#              ('theyd', 1),
#              ('cut', 1),
#              ('money', 1),
#              ('keeps', 1),
#              ('doing', 1),
#              ('angry', 1),
#              ('chucked', 1),
#              ('PlayStation', 1),
#              ('computer', 1),
#              ('play', 1),
#              ('games', 1),
#              ('Bit', 1),
#              ('MegaMutilation', 1),
#              ('Part', 1),
#              ('Three', 1),
#              ('Im', 1),
#              ('okay', 1),
#              ('mainly', 1),
#              ('terrified', 1),
#              ('bats', 1),
#              ('ask', 1),
#              ('weird', 1),
#              ('scar', 1),
#              ('Last', 1),
#              ('Voldemort', 1),
#              ('dont', 1),
#              ('reckon', 1),
#              ('anywhere', 1),
#              ('near', 1),
#              ('Do', 1),
#              ('curse', 1),
#              ('scars', 1),
#              ('sometimes', 1),
#              ('afterward', 1),
#              ('Ill', 1),
#              ('gets', 1),
#              ('shes', 1),
#              ('hunting', 1),
#              ('Say', 1),
#              ('hello', 1),
#              ('Yes', 1),
#              ('point', 1),
#              ('putting', 1),
#              ('dream', 1),
#              ('worried', 1),
#              ('folded', 1),
#              ('27', 1),
#              ('ready', 1),
#              ('feet', 1),
#              ('stretched', 1),
#              ('opened', 1),
#              ('wardrobe', 1),
#              ('Without', 1),
#              ('glancing', 1),
#              ('reflection', 1),
#              ('started', 1),
#              ('dressed', 1),
#              ('28', 1),
#              ('THE', 1),
#              ('INVITATION', 1),
#              ('By', 1),
#              ('seated', 1),
#              ('None', 1),
#              ('entered', 1),
#              ('mornings', 1),
#              ('Daily', 1),
#              ('Mail', 1),
#              ('cutting', 1),
#              ('quarters', 1),
#              ('lips', 1),
#              ('pursed', 1),
#              ('horselike', 1),
#              ('sulky', 1),
#              ('somehow', 1),
#              ('taking', 1),
#              ('space', 1),
#              ('saying', 1),
#              ('took', 1),
#              ('entire', 1),
#              ('side', 1),
#              ('When', 1),
#              ('unsweetened', 1),
#              ('plate', 1),
#              ('tremulous', 1),
#              ('Diddy', 1),
#              ('darling', 1),
#              ('glowered', 1),
#              ('endofyear', 1),
#              ('excuses', 1),
#              ('bad', 1),
#              ('marks', 1),
#              ('gifted', 1),
#              ('whose', 1),
#              ('teachers', 1),
#              ('29', 1),
#              ('maintained', 1),
#              ('swotty', 1),
#              ('nancy', 1),
#              ('anyway', 1),
#              ('also', 1),
#              ('skated', 1),
#              ('accusations', 1),
#              ('bullying', 1),
#              ('Hes', 1),
#              ('boisterous', 1),
#              ('wouldnt', 1),
#              ('fly', 1),
#              ('tearfully', 1),
#              ('However', 1),
#              ('bottom', 1),
#              ('there', 1),
#              ('few', 1),
#              ('wellchosen', 1),
#              ('comments', 1),
#              ('explain', 1),
#              ('No', 1),
#              ('matter', 1),
#              ('wailed', 1),
#              ('bigboned', 1),
#              ('poundage', 1),
#              ('puppy', 1),
#              ('fat', 1),
#              ('growing', 1),
#              ('plenty', 1),
#              ('remained', 1),
#              ('outfitters', 1),
#              ('stock', 1),
#              ('knickerbockers', 1),
#              ('big', 1),
#              ('anymore', 1),
#              ('sharp', 1),
#              ('spotting', 1),
#              ('fingerprints', 1),
#              ('gleaming', 1),
#              ('observing', 1),
#              ('comings', 1),
#              ('goings', 1),
#              ('neighbors', 1),
#              ('simply', 1),
#              ('refused', 1),
#              ('far', 1),
#              ('needing', 1),
#              ('extra', 1),
#              ('nourishment', 1),
#              ('reached', 1),
#              ('roughly', 1),
#              ('size', 1),
#              ('weight', 1),
#              ('young', 1),
#              ('killer', 1),
#              ('whale', 1),
#              ('tantrums', 1),
#              ('arguments', 1),
#              ('shook', 1),
#              ('floor', 1),
#              ('tears', 1),
#              ('new', 1),
#              ('regime', 1),
#              ('begun', 1),
#              ('sheet', 1),
#              ('Smeltings', 1),
#              ('taped', 1),
#              ('fridge', 1),
#              ('emptied', 1),
#              ('favorite', 1),
#              ('fizzy', 1),
#              ('drinks', 1),
#              ('chocolate', 1),
#              ('bars', 1),
#              ('burgers', 1),
#              ('filled', 1),
#              ('instead', 1),
#              ('fruit', 1),
#              ('vegetables', 1),
#              ('sorts', 1),
#              ('rabbit', 1),
#              ('better', 1),
#              ('whole', 1),
#              ('follow', 1),
#              ('passed', 1),
#              ('lot', 1),
#              ('smaller', 1),
#              ('morale', 1),
#              ('least', 1),
#              ('eat', 1),
#              ('30', 1),
#              ('idea', 1),
#              ('following', 1),
#              ('wind', 1),
#              ('expected', 1),
#              ('survive', 1),
#              ('carrot', 1),
#              ('sticks', 1),
#              ('friends', 1),
#              ('pleas', 1),
#              ('occasion', 1),
#              ('magnificently', 1),
#              ('box', 1),
#              ('stuffed', 1),
#              ('sugarfree', 1),
#              ('snacks', 1),
#              ('parents', 1),
#              ('dentists', 1),
#              ('gamekeeper', 1),
#              ('obliged', 1),
#              ('sack', 1),
#              ('homemade', 1),
#              ('rock', 1),
#              ('touched', 1),
#              ('experience', 1),
#              ('Hagrids', 1),
#              ('cooking', 1),
#              ('owl', 1),
#              ('fruitcake', 1),
#              ('assorted', 1),
#              ('meat', 1),
#              ('pies', 1),
#              ('Poor', 1),
#              ('elderly', 1),
#              ('feeble', 1),
#              ('five', 1),
#              ('days', 1),
#              ('recover', 1),
#              ('journey', 1),
#              ('completely', 1),
#              ('ignored', 1),
#              ('four', 1),
#              ('superb', 1),
#              ('each', 1),
#              ('left', 1),
#              ('forward', 1),
#              ('real', 1),
#              ('ate', 1),
#              ('without', 1),
#              ('complaint', 1),
#              ('deep', 1),
#              ('sniff', 1),
#              ('disapproval', 1),
#              ('Is', 1),
#              ('grumpily', 1),
#              ('nodded', 1),
#              ('pointedly', 1),
#              ('eyeing', 1),
#              ('sour', 1),
#              ('piggy', 1),
#              ('sigh', 1),
#              ('ruffled', 1),
#              ('bushy', 1),
#              ('picked', 1),
#              ('spoon', 1),
#              ('31', 1),
#              ('heaved', 1),
#              ('chair', 1),
#              ('Quick', 1),
#              ('flash', 1),
#              ('occupied', 1),
#              ('kettle', 1),
#              ('stole', 1),
#              ('talking', 1),
#              ('laughing', 1),
#              ('answering', 1),
#              ('curtly', 1),
#              ('ripping', 1),
#              ('teapot', 1),
#              ('curiously', 1),
#              ('wait', 1),
#              ('livid', 1),
#              ('You', 1),
#              ('barked', 1),
#              ('In', 1),
#              ('living', 1),
#              ('Now', 1),
#              ('Bewildered', 1),
#              ('earth', 1),
#              ('supposed', 1),
#              ('done', 1),
#              ('followed', 1),
#              ('next', 1),
#              ('sharply', 1),
#              ('marching', 1),
#              ('fireplace', 1),
#              ('turning', 1),
#              ('pronounce', 1),
#              ('arrest', 1),
#              ('dearly', 1),
#              ('loved', 1),
#              ('should', 1),
#              ('tested', 1),
#              ('early', 1),
#              ('especially', 1),
#              ('strain', 1),
#              ('lack', 1),
#              ('therefore', 1),
#              ('settled', 1),
#              ('politely', 1),
#              ('puzzled', 1),
#              ('brandished', 1),
#              ('About', 1),
#              ('32', 1),
#              ('confusion', 1),
#              ('increased', 1),
#              ('glared', 1),
#              ('began', 1),
#              ('read', 1),
#              ('Mr', 1),
#              ('introduced', 1),
#              ('deal', 1),
#              ('As', 1),
#              ('final', 1),
#              ('Quidditch', 1),
#              ('World', 1),
#              ('Cup', 1),
#              ('takes', 1),
#              ('place', 1),
#              ('Monday', 1),
#              ('night', 1),
#              ('husband', 1),
#              ('Arthur', 1),
#              ('prime', 1),
#              ('connections', 1),
#              ('Department', 1),
#              ('Magical', 1),
#              ('Games', 1),
#              ('Sports', 1),
#              ('will', 1),
#              ('match', 1),
#              ('onceinalifetime', 1),
#              ('opportunity', 1),
#              ('Britain', 1),
#              ('hosted', 1),
#              ('cup', 1),
#              ('thirty', 1),
#              ('extremely', 1),
#              ('course', 1),
#              ('glad', 1),
#              ('stay', 1),
#              ('remainder', 1),
#              ('holidays', 1),
#              ('safely', 1),
#              ('answer', 1),
#              ('quickly', 1),
#              ('normal', 1),
#              ('Muggle', 1),
#              ('our', 1),
#              ('knows', 1),
#              ('Hoping', 1),
#              ('soon', 1),
#              ('Yours', 1),
#              ('sincerely', 1),
#              ('Molly', 1),
#              ('PS', 1),
#              ('weve', 1),
#              ('33', 1),
#              ('reading', 1),
#              ('breast', 1),
#              ('drew', 1),
#              ('else', 1),
#              ('Look', 1),
#              ('held', 1),
#              ('envelope', 1),
#              ('fight', 1),
#              ('laugh', 1),
#              ('Every', 1),
#              ('covered', 1),
#              ('except', 1),
#              ('inch', 1),
#              ('squeezed', 1),
#              ('address', 1),
#              ('mistake', 1),
#              ('flashed', 1),
#              ('gritted', 1),
#              ('Very', 1),
#              ('interested', 1),
#              ('Seemed', 1),
#              ('think', 1),
#              ('funny', 1),
#              ('Other', 1),
#              ('making', 1),
#              ('fuss', 1),
#              ('lived', 1),
#              ('touchy', 1),
#              ('slightly', 1),
#              ('ordinary', 1),
#              ('Their', 1),
#              ('worst', 1),
#              ('connected', 1),
#              ('distantly', 1),
#              ('like', 1),
#              ('glaring', 1),
#              ('tried', 1),
#              ('expression', 1),
#              ('neutral', 1),
#              ('If', 1),
#              ('treat', 1),
#              ('lifetime', 1),
#              ('waited', 1),
#              ('merely', 1),
#              ('continued', 1),
#              ('glare', 1),
#              ('decided', 1),
#              ('break', 1),
#              ('silence', 1),
#              ('asked', 1),
#              ('34', 1),
#              ('slight', 1),
#              ('spasm', 1),
#              ('crossed', 1),
#              ('bristled', 1),
#              ('battle', 1),
#              ('fundamental', 1),
#              ('instincts', 1),
#              ('conflict', 1),
#              ('Allowing', 1),
#              ('happy', 1),
#              ('struggled', 1),
#              ('against', 1),
#              ('thirteen', 1),
#              ('On', 1),
#              ('allowing', 1),
#              ('disappear', 1),
#              ('rid', 1),
#              ('weeks', 1),
#              ('earlier', 1),
#              ('hated', 1),
#              ('having', 1),
#              ('give', 1),
#              ('thinking', 1),
#              ('staring', 1),
#              ('signature', 1),
#              ('distaste', 1),
#              ('Youve', 1),
#              ('Shes', 1),
#              ('friend', 1),
#              ('Rons', 1),
#              ('meeting', 1),
#              ('Hog', 1),
#              ('end', 1),
#              ('term', 1),
#              ('almost', 1),
#              ('Express', 1),
#              ('Nobody', 1),
#              ('mentioned', 1),
#              ('household', 1),
#              ('screwed', 1),
#              ('remember', 1),
#              ('Dumpy', 1),
#              ('Load', 1),
#              ('children', 1),
#              ('hair', 1),
#              ('frowned', 1),
#              ('rich', 1),
#              ('dumpy', 1),
#              ('achieved', 1),
#              ('hed', 1),
#              ('threatening', 1),
#              ('age', 1),
#              ('become', 1),
#              ('wider', 1),
#              ('tall', 1)])

# %%
# Define a function to load English words from a file into a set
def load_english_words(filename):
    english_words = set()
    encodings = ['utf-8', 'latin-1', 'iso-8859-1']

    try:
        for encoding in encodings:
            with open(filename, 'r', encoding=encoding, errors='ignore') as file:
                for line in file:
                    english_words.add(line.strip().lower()) 
            break
    except FileNotFoundError:
        print(f"File '{filename}' not found.")
    except Exception as e:
        print(f"Error reading '{filename}' with encoding '{encoding}': {str(e)}")

    return english_words

# Define a function to count non-English words in a text file
def count_non_english_words(filename, english_words):
    word_counts = {}

    try:
        with open(filename, 'r', encoding='utf-8') as file:
            for line in file:
                words = line.split()
                
                for word in words:
                    word = word.lower()
                    if word not in english_words:
                        if word in word_counts:
                            word_counts[word] += 1
                        else:
                            word_counts[word] = 1
    except FileNotFoundError:
        print(f"File '{filename}' not found.")
    
    return word_counts

english_words_file = "engmix.txt"
text_file = "file2.txt"
english_words = load_english_words(english_words_file)
word_counts = count_non_english_words(text_file, english_words)
sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)


for word, count in sorted_word_counts:
    print(f"{word}: {count} times")
# Out:
# —: 19 times
# mr.: 17 times
# ...: 14 times
# |: 10 times
# –: 10 times
# j.k.: 10 times
# rowling: 10 times
# harry,: 8 times
# dobby: 8 times
# weasley: 6 times
# harry’s: 6 times
# winky: 6 times
# —”: 5 times
# harry.: 5 times
# it.: 4 times
# ron,: 4 times
# weasley,: 4 times
# sir,: 4 times
# “oh: 3 times
# hermione: 3 times
# him.: 3 times
# “you: 3 times
# don’t: 3 times
# hands.: 3 times
# too,: 3 times
# field.: 3 times
# them.: 3 times
# them,: 3 times
# malfoy: 3 times
# “but: 3 times
# sir!”: 3 times
# winky,: 3 times
# “how: 3 times
# “house-elves: 3 times
# haven’t: 2 times
# they?: 2 times
# they’ve: 2 times
# it’s: 2 times
# know,”: 2 times
# tea,: 2 times
# feet,: 2 times
# “you’ll: 2 times
# i’m: 2 times
# barty: 2 times
# “what’s: 2 times
# enough,”: 2 times
# “it’s: 2 times
# players,: 2 times
# hand,: 2 times
# hadn’t: 2 times
# omnioculars: 2 times
# grinning.: 2 times
# “and: 2 times
# let’s: 2 times
# loudly,: 2 times
# stadium.: 2 times
# wizards.: 2 times
# here,: 2 times
# light,: 2 times
# mrs.: 2 times
# was,: 2 times
# dobby’s: 2 times
# “i: 2 times
# said,: 2 times
# him?”: 2 times
# “ah,: 2 times
# sir,”: 2 times
# head,: 2 times
# sir.: 2 times
# can’t: 2 times
# sir.”: 2 times
# ”: 2 times
# again.: 2 times
# dobby,: 2 times
# says,: 2 times
# told.: 2 times
# seat,: 2 times
# potter,: 2 times
# that’s: 2 times
# fudge,: 2 times
# “harry: 2 times
# ah,: 2 times
# house-elf’s: 2 times
# son,: 2 times
# 101: 1 times
# “we: 1 times
# details!”: 1 times
# bagman,: 1 times
# midges.: 1 times
# “they’ve: 1 times
# signed,: 1 times
# agreed,: 1 times
# kids’ll: 1 times
# anyway.: 1 times
# mean,: 1 times
# hogwarts: 1 times
# “ludo,: 1 times
# bulgarians,: 1 times
# sharply,: 1 times
# bagman’s: 1 times
# short.: 1 times
# “thank: 1 times
# weatherby.”: 1 times
# undrunk: 1 times
# rise;: 1 times
# merrily.: 1 times
# “see: 1 times
# later!”: 1 times
# said.: 1 times
# commentating!”: 1 times
# waved,: 1 times
# curtly,: 1 times
# disapparated.: 1 times
# hogwarts,: 1 times
# dad?”: 1 times
# once.: 1 times
# “what: 1 times
# about?”: 1 times
# mr.weasley,: 1 times
# smiling.: 1 times
# information,: 1 times
# it,”: 1 times
# stiffly.: 1 times
# “mr.: 1 times
# it.”: 1 times
# up,: 1 times
# weatherby,”: 1 times
# fred.: 1 times
# on.: 1 times
# dusk,: 1 times
# anticipation,: 1 times
# 102: 1 times
# wizards,: 1 times
# disappeared:: 1 times
# everywhere.: 1 times
# apparating: 1 times
# merchandise.: 1 times
# ireland,: 1 times
# shamrocks,: 1 times
# roared,: 1 times
# waved;: 1 times
# firebolts: 1 times
# flew,: 1 times
# themselves.: 1 times
# “been: 1 times
# this,”: 1 times
# salesmen,: 1 times
# souvenirs.: 1 times
# rosette,: 1 times
# viktor: 1 times
# krum,: 1 times
# seeker.: 1 times
# krum: 1 times
# ron’s: 1 times
# “wow,: 1 times
# these!”: 1 times
# binoculars,: 1 times
# dials.: 1 times
# “omnioculars,”: 1 times
# saleswizard: 1 times
# eagerly.: 1 times
# play-by-play: 1 times
# each.”: 1 times
# 103: 1 times
# “wish: 1 times
# now,”: 1 times
# omnioculars.: 1 times
# “three: 1 times
# pairs,”: 1 times
# wizard.: 1 times
# “no: 1 times
# bother,”: 1 times
# red.: 1 times
# parents,: 1 times
# did.: 1 times
# won’t: 1 times
# christmas,”: 1 times
# him,: 1 times
# hermione’s: 1 times
# “for: 1 times
# years,: 1 times
# mind.”: 1 times
# “fair: 1 times
# “oooh,: 1 times
# thanks,: 1 times
# harry,”: 1 times
# hermione.: 1 times
# i’ll: 1 times
# programs,: 1 times
# lighter,: 1 times
# tents.: 1 times
# bill,: 1 times
# charlie,: 1 times
# ginny: 1 times
# flag.: 1 times
# gold.: 1 times
# deep,: 1 times
# woods,: 1 times
# once,: 1 times
# trees,: 1 times
# time!”: 1 times
# “come: 1 times
# on,: 1 times
# go!”: 1 times
# 104: 1 times
# quidditch: 1 times
# purchases,: 1 times
# lead,: 1 times
# wood,: 1 times
# lantern-: 1 times
# trail.: 1 times
# laughter,: 1 times
# singing.: 1 times
# infectious;: 1 times
# couldn’t: 1 times
# minutes,: 1 times
# field,: 1 times
# “seats: 1 times
# thousand,”: 1 times
# awestruck: 1 times
# face.: 1 times
# “ministry: 1 times
# year.: 1 times
# muggle: 1 times
# muggles: 1 times
# year,: 1 times
# them,”: 1 times
# fondly,: 1 times
# 105: 1 times
# entrance,: 1 times
# “prime: 1 times
# seats!”: 1 times
# tickets.: 1 times
# “top: 1 times
# box!: 1 times
# upstairs,: 1 times
# arthur,: 1 times
# go.”: 1 times
# purple.: 1 times
# crowd,: 1 times
# right.: 1 times
# weasley’s: 1 times
# climbing,: 1 times
# box,: 1 times
# posts.: 1 times
# purple-and-gilt: 1 times
# weasleys,: 1 times
# imagined.: 1 times
# seats,: 1 times
# itself.: 1 times
# position.: 1 times
# hoops,: 1 times
# high;: 1 times
# level,: 1 times
# blackboard.: 1 times
# giant’s: 1 times
# again;: 1 times
# it,: 1 times
# bluebottle:: 1 times
# safe,: 1 times
# reliable,: 1 times
# built-in: 1 times
# anti-burglar: 1 times
# skower’s: 1 times
# all-purpose: 1 times
# remover:: 1 times
# pain,: 1 times
# stain!: 1 times
# gladrags: 1 times
# wizardwear: 1 times
# london,: 1 times
# paris,: 1 times
# hogsmeade: 1 times
# 106: 1 times
# empty,: 1 times
# creature,: 1 times
# chair,: 1 times
# toga,: 1 times
# long,: 1 times
# batlike: 1 times
# familiar.: 1 times
# “dobby?”: 1 times
# incredulously.: 1 times
# fingers,: 1 times
# tomato.: 1 times
# wasn’t: 1 times
# however,: 1 times
# house-elf,: 1 times
# been.: 1 times
# owners,: 1 times
# family.: 1 times
# “did: 1 times
# dobby?”: 1 times
# fingers.: 1 times
# been,: 1 times
# teeny,: 1 times
# voice,: 1 times
# house-elf: 1 times
# female.: 1 times
# look.: 1 times
# interest.: 1 times
# “sorry,”: 1 times
# elf,: 1 times
# knew.”: 1 times
# elf.: 1 times
# face,: 1 times
# lit.: 1 times
# “my: 1 times
# you,: 1 times
# scar.: 1 times
# potter!”: 1 times
# 107: 1 times
# “yeah,: 1 times
# am,”: 1 times
# time,: 1 times
# awestruck.: 1 times
# he?”: 1 times
# “how’s: 1 times
# “ah: 1 times
# disrespect,: 1 times
# favor,: 1 times
# free.”: 1 times
# “why?”: 1 times
# aback.: 1 times
# “freedom: 1 times
# sadly.: 1 times
# “ideas: 1 times
# station,: 1 times
# position,: 1 times
# “why: 1 times
# not?”: 1 times
# half-octave: 1 times
# whispered,: 1 times
# “he: 1 times
# work,: 1 times
# “paying?”: 1 times
# blankly.: 1 times
# “well: 1 times
# shouldn’t: 1 times
# paid?”: 1 times
# half-hidden: 1 times
# paid,: 1 times
# squeak.: 1 times
# “no,: 1 times
# no,: 1 times
# no.: 1 times
# down,: 1 times
# dobby.: 1 times
# jinks,: 1 times
# house-elf.: 1 times
# this,: 1 times
# you’s: 1 times
# 108: 1 times
# creatures,: 1 times
# goblin.”: 1 times
# “well,: 1 times
# fun,”: 1 times
# fun,: 1 times
# potter,”: 1 times
# firmly,: 1 times
# all,: 1 times
# potter”: 1 times
# comes,: 1 times
# “why’s: 1 times
# heights?”: 1 times
# frowning.: 1 times
# “master: 1 times
# potter.: 1 times
# busy,”: 1 times
# her.: 1 times
# “winky: 1 times
# master’s: 1 times
# tent,: 1 times
# house-elf.”: 1 times
# others.: 1 times
# “so: 1 times
# house-elf?”: 1 times
# muttered.: 1 times
# “weird: 1 times
# things,: 1 times
# aren’t: 1 times
# they?”: 1 times
# “dobby: 1 times
# weirder,”: 1 times
# fervently.: 1 times
# “wild!”: 1 times
# side.: 1 times
# ...”: 1 times
# 109: 1 times
# hermione,: 1 times
# meanwhile,: 1 times
# velvet-covered,: 1 times
# program.: 1 times
# “: 1 times
# ‘a: 1 times
# match,’: 1 times
# aloud.: 1 times
# watching,”: 1 times
# weasley.: 1 times
# “national: 1 times
# land,: 1 times
# know,: 1 times
# show.”: 1 times
# hour.: 1 times
# hedgehog.: 1 times
# himself,: 1 times
# arrived,: 1 times
# shattered.: 1 times
# embarrassed,: 1 times
# friend.: 1 times
# before,: 1 times
# fashion,: 1 times
# didn’t: 1 times
# english.: 1 times
# now,: 1 times
# you-know-who: 1 times
# excitedly,: 1 times
# “knew: 1 times
# we’d: 1 times
# end,”: 1 times
# “i’m: 1 times
# languages;: 1 times
# thing.: 1 times
# 110: 1 times
# seat.: 1 times
# here’s: 1 times
# lucius!”: 1 times
# quickly.: 1 times
# still-empty: 1 times
# owners:: 1 times
# lucius: 1 times
# malfoy;: 1 times
# draco;: 1 times
# draco’s: 1 times
# mother.: 1 times
# hogwarts.: 1 times
# white-blond: 1 times
# hair,: 1 times
# father.: 1 times
# too;: 1 times
# slim,: 1 times
# nice-looking: 1 times
# nose.: 1 times
# fudge,”: 1 times
# malfoy,: 1 times
# magic.: 1 times
# you?: 1 times
# you’ve: 1 times
# wife,: 1 times
# narcissa?: 1 times
# draco?”: 1 times
# do,: 1 times
# do?”: 1 times
# malfoy.: 1 times
# oblansk: 1 times
# obalonsk: 1 times
# well,: 1 times
# he’s: 1 times
# magic,: 1 times
# anyway,: 1 times
# mind.: 1 times
# daresay?”: 1 times
# moment.: 1 times
# face-to-face:: 1 times
# blotts’: 1 times
# bookshop,: 1 times
# fight.: 1 times
# malfoy’s: 1 times
# row.: 1 times
